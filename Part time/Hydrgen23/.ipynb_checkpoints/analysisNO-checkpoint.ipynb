# %%
import csv
import pandas as pd

# %%
path = 'stations.zip'
pathCSV = 'Electric and Alternative Fuel Charging Stations.csv'

# %%
from zipfile import *
with ZipFile(path, 'r') as zip:
    zip.extractall()

# %%
data = pd.read_csv(pathCSV, sep=',', low_memory=False)
data[17:19]
# Out:
#    Fuel Type Code                                       Station Name  \
# 17            CNG                                Sparq - Baton Rouge
# 18            CNG  Clean Energy - City of Santa Fe - Santa Fe Tra...
#
#        Street Address                 Intersection Directions         City  \
# 17  8968 S Choctaw Dr  2 miles east of Airline Hwy/Highway 61  Baton Rouge
# 18     2931 Rufina St                                     NaN     Santa Fe
#
#    State    ZIP  Plus4 Station Phone Status Code  ... EV Pricing (French)  \
# 17    LA  70815    NaN  844-772-7764           E  ...                 NaN
# 18    NM  87507    NaN  866-809-4869           E  ...                 NaN
#
#    LPG Nozzle Types Hydrogen Pressures Hydrogen Standards CNG Fill Type Code  \
# 17              NaN                NaN                NaN                  Q
# 18              NaN                NaN                NaN                  Q
#
#       CNG PSI CNG Vehicle Class  LNG Vehicle Class  \
# ...

# %%
data = data.drop(['Intersection Directions'], axis=1)

# %%
data.columns
# Out:
# Index(['Fuel Type Code', 'City', 'State', 'ZIP', 'Plus4', 'Station Phone',
#        'Status Code', 'Expected Date', 'Groups With Access Code',
#        'Access Days Time', 'Cards Accepted', 'BD Blends', 'NG Fill Type Code',
#        'NG PSI', 'EV Level1 EVSE Num', 'EV Level2 EVSE Num',
#        'EV DC Fast Count', 'EV Other Info', 'EV Network', 'EV Network Web',
#        'Geocode Status', 'Latitude', 'Longitude', 'Date Last Confirmed', 'ID',
#        'Updated At', 'Owner Type Code', 'Federal Agency ID',
#        'Federal Agency Name', 'Open Date', 'Hydrogen Status Link',
#        'NG Vehicle Class', 'LPG Primary', 'E85 Blender Pump',
#        'EV Connector Types', 'Country', 'Intersection Directions (French)',
#        'Access Days Time (French)', 'BD Blends (French)',
#        'Groups With Access Code (French)', 'Hydrogen Is Retail', 'Access Code',
#        'Access Detail Code', 'Federal Agency Code', 'Facility Type',
#        'CNG Dispenser Num', 'CNG On-Site Renewable Source',
# ...

# %%
df = data[['Fuel Type Code',
           'EV Level1 EVSE Num',
           'EV Level2 EVSE Num',
           'EV DC Fast Count',
           'Latitude', 'Longitude',
           'ID',
           'Open Date', 
           'Hydrogen Status Link',
           'LPG Primary', 
           'E85 Blender Pump',
           'Hydrogen Is Retail', 
       'CNG Dispenser Num', 'CNG On-Site Renewable Source',
       'CNG Total Compression Capacity', 'CNG Storage Capacity',
       'LNG On-Site Renewable Source', 'E85 Other Ethanol Blends',
       'EV Pricing', 'EV Pricing (French)', 'LPG Nozzle Types',
       'Hydrogen Pressures', 'Hydrogen Standards', 'CNG Fill Type Code',
       'CNG PSI', 'CNG Vehicle Class', 'LNG Vehicle Class',
       'EV On-Site Renewable Source']].copy()
# Out:
#       Fuel Type Code         City State    ZIP  Plus4 Station Phone  \
# 0                CNG   Montgomery    AL  36107    NaN           NaN
# 1                CNG      Atlanta    GA  30303    NaN  770-350-3000
# 2                CNG      Atlanta    GA  30324    NaN           NaN
# 3                CNG      Atlanta    GA  30336    NaN           NaN
# 4                CNG   Fort Smith    AR  72903    NaN  479-783-3188
# ...              ...          ...   ...    ...    ...           ...
# 70401           ELEC    Milwaukee    WI  53212    NaN  888-758-4389
# 70402           ELEC       Austin    TX  78702    NaN  888-758-4389
# 70403           ELEC       Loomis    CA  95650    NaN  877-455-3833
# 70404           ELEC  Los Angeles    CA  91342    NaN  888-356-8911
# 70405           ELEC  Los Angeles    CA  91405    NaN  888-356-8911
#
#       Status Code Expected Date            Groups With Access Code  \
# 0               E           NaN                            Private
# ...
