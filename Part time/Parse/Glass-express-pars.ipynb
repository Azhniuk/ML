# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

items = []
url = 'https://shop.glass-express.ua/rdx-2013-2018'

page = requests.get(url)

filteredNews = []
allNews = []
soup = BeautifulSoup(page.text, "html.parser")

all = soup.findAll('select', class_='home-filter__field')
allVal = soup.findAll('value')
print(all)
# Out:
# [<select class="home-filter__field" id="insert_0" name="" onchange="getNextData(0, this.value);">
# <option value="0">
#                                                                             Марка автомобіля                                                                    </option>
# <option selected="selected" value="26511">ACURA</option>
# <option value="26520">AUDI</option>
# <option value="26584">BMW</option>
# <option value="26660">BUICK</option>
# <option value="26668">BYD</option>
# <option value="26671">CADILLAC</option>
# <option value="26676">CHERY</option>
# <option value="26699">CHEVROLET</option>
# <option value="26758">CHRYSLER</option>
# <option value="26766">CITROEN</option>
# <option value="26832">DACIA</option>
# <option value="26851">DAEWOO</option>
# <option value="26873">DAF</option>
# <option value="26884">DAIHATSU</option>
# <option value="26889">DODGE</option>
# <option value="26912">FIAT</option>
# <option value="26978">FORD</option>
# ...

# %%
import requests

with open('sitemap.xml', 'r') as f:
    data = f.read() 

bs_data = BeautifulSoup(data, 'xml') 
b_name = bs_data.find_all('loc') 

for link in b_name :
    
    print(link.get_text())
# Out:
# https://shop.glass-express.ua/
# https://shop.glass-express.ua/klienty-o-nas
# https://shop.glass-express.ua/en/klienty-o-nas
# https://shop.glass-express.ua/ua/klienty-o-nas
# https://shop.glass-express.ua/ua/o-kompanii
# https://shop.glass-express.ua/dostavka-i-oplata
# https://shop.glass-express.ua/kontakty
# https://shop.glass-express.ua/garantiia-i-vozvrat
# https://shop.glass-express.ua/zapisatsia-na-servis
# https://shop.glass-express.ua/publichnyi-dogovor
# https://shop.glass-express.ua/servisni-tsentri
# https://shop.glass-express.ua/q3-2011-2018
# https://shop.glass-express.ua/q5-2008-2017
# https://shop.glass-express.ua/q7-2006-2015
# https://shop.glass-express.ua/500-2007
# https://shop.glass-express.ua/500e-2013
# https://shop.glass-express.ua/500l-2012
# https://shop.glass-express.ua/canter-1985-1993
# https://shop.glass-express.ua/courier-1996-2002
# https://shop.glass-express.ua/edge-2015
# https://shop.glass-express.ua/ducato-1994-2006
# ...

# %%
from bs4 import BeautifulSoup 

with open('sitemap.xml', 'r') as f:
    data = f.read() 

# Passing the stored data inside the beautifulsoup parser 
bs_data = BeautifulSoup(data, 'xml') 

#print(bs_data) 
exclusion = ['klienty-o-nas', 'o-kompanii']

for link in b_name :
    print(link.get_text())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17096\4145203204.py in <module>
#      10 exclusion = ['klienty-o-nas', 'o-kompanii']
#      11
# ---> 12 for link in b_name :
#      13     print(link.get_text())
#
# TypeError: 'NoneType' object is not iterable

# %%
'''
for data in all:
    if data.find('span', class_='time2 time3') is not None:
        filteredNews.append(data.text)
        
with open("sitemap.xml", "wb") as handle:
    handle.write(r.content)

        '''

# %%
'''
for child in bs_data.iter():
    i = child.tag.find('}')+1
    if child.tag[i:] == 'loc':
        if child.text.split('/')[3]=='ua':
            if child.text.split('/')[4] not in exclusion:
                print( child.text)
'''

# %%
import requests

url = "https://shop.glass-express.ua/sitemap.xml"
r = requests.get(url, stream=True)

with open("sitemap.xml", "wb") as handle:
    handle.write(r.content)

##   

import xml.etree.ElementTree as ET
tree = ET.parse('sitemap.xml')
root = tree.getroot()

exclusion = ['klienty-o-nas', 'o-kompanii']
for child in root.iter():
    i = child.tag.find('}')+1
    if child.tag[i:] == 'loc':
        if child.text.split('/')[3]=='ua':
            if child.text.split('/')[4] not in exclusion:
                print( child.text)
