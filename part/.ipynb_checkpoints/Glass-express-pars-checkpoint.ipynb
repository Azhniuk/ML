# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

items = []
url = 'https://shop.glass-express.ua/rdx-2013-2018'

page = requests.get(url)

filteredNews = []
allNews = []
soup = BeautifulSoup(page.text, "html.parser")

all = soup.findAll('select', class_='home-filter__field')
allVal = soup.findAll('value')
print(all)
# Out:
# [<select class="home-filter__field" id="insert_0" name="" onchange="getNextData(0, this.value);">
# <option value="0">
#                                                                             Марка автомобіля                                                                    </option>
# <option selected="selected" value="26511">ACURA</option>
# <option value="26520">AUDI</option>
# <option value="26584">BMW</option>
# <option value="26660">BUICK</option>
# <option value="26668">BYD</option>
# <option value="26671">CADILLAC</option>
# <option value="26676">CHERY</option>
# <option value="26699">CHEVROLET</option>
# <option value="26758">CHRYSLER</option>
# <option value="26766">CITROEN</option>
# <option value="26832">DACIA</option>
# <option value="26851">DAEWOO</option>
# <option value="26873">DAF</option>
# <option value="26884">DAIHATSU</option>
# <option value="26889">DODGE</option>
# <option value="26912">FIAT</option>
# <option value="26978">FORD</option>
# <option value="26975">FORD TRUCK</option>
# <option value="27090">FOTON</option>
# <option value="27093">GEELY</option>
# <option value="27107">GMC</option>
# <option value="27111">GREAT WALL</option>
# <option value="27119">HONDA</option>
# <option value="27187">HYUNDAI</option>
# <option value="27281">INFINITI</option>
# <option value="27311">ISUZU</option>
# <option value="27318">IVECO</option>
# <option value="27334">JAGUAR</option>
# <option value="27342">JEEP</option>
# <option value="27369">KIA</option>
# <option value="28457">LADA</option>
# <option value="27460">LANCIA</option>
# <option value="27464">LAND ROVER</option>
# <option value="27491">LEXUS</option>
# <option value="27533">LIFAN</option>
# <option value="27536">LINCOLN</option>
# <option value="27545">MAN</option>
# <option value="29012">MAZDA</option>
# <option value="27629">MERCEDES</option>
# <option value="27619">MERCEDES TRUCK</option>
# <option value="27738">MG</option>
# <option value="27745">MINI</option>
# <option value="27755">MITSUBISHI</option>
# <option value="27752">MITSUBISHI TRUCK</option>
# <option value="27822">NISSAN</option>
# <option value="27923">OPEL</option>
# <option value="27996">PEUGEOT</option>
# <option value="28505">PORSCHE</option>
# <option value="28515">RAVON</option>
# <option value="28528">RENAULT</option>
# <option value="28518">RENAULT TRUCK</option>
# <option value="28623">ROVER</option>
# <option value="28626">SAMAND</option>
# <option value="28629">SCANIA</option>
# <option value="28634">SEAT</option>
# <option value="28676">SKODA</option>
# <option value="28718">SMART</option>
# <option value="28723">SSANGYONG</option>
# <option value="28071">SUBARU</option>
# <option value="28097">SUZUKI</option>
# <option value="28119">TESLA</option>
# <option value="28130">TOYOTA</option>
# <option value="28127">TOYOTA TRUCK</option>
# <option value="28261">VOLKSWAGEN</option>
# <option value="28398">VOLVO</option>
# <option value="28388">VOLVO TRUCK</option>
# <option value="28448">ВАЗ</option>
# <option value="28460">ГАЗ</option>
# <option value="28463">ЗАЗ</option>
# <option value="28473">УАЗ</option>
# <option value="28476">УНІВЕРСАЛЬНА ГРУПА</option>
# </select>, <select class="home-filter__field" id="insert_1" name="" onchange="getNextData(1, this.value);">
# <option value="0">
#                                                                                     Модель автомобіля                                                                            </option>
# <option value="26512">MDX</option>
# <option selected="selected" value="26515">RDX</option>
# <option value="26518">TLX</option>
# </select>, <select class="home-filter__field" id="insert_2" name="" onchange="getNextData(2, this.value);">
# <option value="0">
#                                                                                     Модифікація                                                                            </option>
# <option value="26516">RDX 2006-2012</option>
# <option selected="selected" value="26517">RDX 2013-2018</option>
# </select>]

# %%
'''
for data in all:
    if data.find('span', class_='time2 time3') is not None:
        filteredNews.append(data.text)
        '''
